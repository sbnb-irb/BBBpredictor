# %%
from chemicalchecker import ChemicalChecker

cc = ChemicalChecker("/aloy/web_checker/current")
# Out:
# 2020-03-03 17:33:46,308 chemicalchecker.core.chemcheck.ChemicalChecker [DEBUG   ] ChemicalChecker with root: /aloy/web_checker/current

# %%
from chemicalchecker.core.sign1_dev import sign1
for ds in cc.datasets_exemplary():
    s1 = sign1(cc.signature(ds, "sign1").signature_path, ds)
    s1.optimal_t()
# Out:
# 2020-03-03 17:34:26,583 chemicalchecker.core.chemcheck.ChemicalChecker [DEBUG   ] signature path: /aloy/web_checker/current/full/A/A1/A1.001/sign1
# 2020-03-03 17:34:26,584 chemicalchecker.core.data.DataFactory [DEBUG   ] initializing object sign1
# 2020-03-03 17:34:26,587 chemicalchecker.core.sign1.sign1 [DEBUG   ] signature path is: /aloy/web_checker/current/full/A/A1/A1.001/sign1
# 2020-03-03 17:34:26,587 chemicalchecker.core.sign1.sign1 [WARNING ] Sign1 using default value (True) for discrete parameter
# 2020-03-03 17:34:26,588 chemicalchecker.core.sign1_dev.sign1 [DEBUG   ] signature path is: /aloy/web_checker/current/full/A/A1/A1.001/sign1
# 2020-03-03 17:34:26,589 chemicalchecker.core.sign1_dev.sign1 [DEBUG   ] Getting neighbors instance
# 2020-03-03 17:34:26,590 chemicalchecker.core.sign1_dev.sign1 [DEBUG   ] signature path is: /aloy/web_checker/current/reference/A/A1/A1.001/sign1
# ...

# %%
accus = s1.optimal_t()

# %%
accus

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.scatter([x[0] for x in accus], [x[1] for x in accus], color="black", s = 10)
plt.xlabel("Neighbors")
plt.ylabel("Accuracy")

# %%
from scipy.signal import savgol_filter
yhat = savgol_filter([x[1] for x in accus], 11, 3)

# %%
plt.plot(yhat)

# %%
find_peaks([x[1] for x in accus])

# %%
s1.recommended_neighbors(True).shape

# %%
sign.signature_path

# %%
ls /aloy/web_checker/current/full/B/B1/B1.001/neig1/

# %%
s1_ref = s1.get_molset("reference")

# %%
n1_ref = s1_ref.get_neig()

# %%
neig_ref[:]

# %%
n1_ref[:10]["indices"]

# %%
import numpy as np
for i in range(5, 100, 2):
    print(i)
